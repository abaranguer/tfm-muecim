# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('50-labels-training-losses.csv')

# %%
plot1 = df.plot.line(x = 'Epoch', y = ['Training Loss', 'Validation Loss'] , color = ['blue', 'red'])

# %%
fig1 = plot1.get_figure()
fig1.savefig('50-labels-training-losses.png')

# %%
df = pd.read_csv('50-labels-training-metrics.csv')

# %%
plot2 = df.plot.line(x = 'Epoch', y = ['F1','Roc Auc','Accuracy'] , color = ['blue', 'red', 'green'])

# %%
fig2 = plot2.get_figure()
fig2.savefig('50-labels-training-metrics.png')

# %%
df2 = pd.read_csv('50-labels-test-set-metrics.csv')

# %%
df2.columns
# Out:
# Index(['epoch', 'f1', 'roc_auc', 'accuracy'], dtype='object')

# %%
plot3 = df2.plot.line(x = 'epoch', y = ['f1', 'roc_auc', 'accuracy'] , color = ['blue', 'red', 'green'])

# %%
fig3 = plot3.get_figure()
fig3.savefig('50-labels-test-set-metrics.png')
