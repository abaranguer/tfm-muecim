# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# api-key-wand-library.txt		   tfm_CreateFileIndices.py
# drive					   tfm_CreateLabelIndex.py
# EURLEX57KDataFrame.csv			   tfm_DatasetAnalyzer.py
# EURLEX57K.json				   tfm_EURLEX57KDataFrameBuilder.py
# eurovoc-info.txt			   tfm_EURLEX57KDataset.py
# FilesIndexShort.txt			   tfm_EURLEX57KMainBodyLinesGenerator.py
# FilesIndex.txt				   tfm_LabelIndex.py
# LabelIndex.txt				   tfm_LabelLoader.py
# ReducedEURLEX57KDataFrame.csv		   tfm_muecim.ipynb
# ReducedFileIndex.txt			   tfm_Pipeline.py
# reduced-model-1-graphs.ipynb		   tfm_ReducedDatasetBuilder.py
# reduced-model-1-test-set-metrics.csv	   tfm_ReducedEURLEX57KDataFrameBuilder.py
# reduced-model-1-training-losses-graph.csv  tfm_ReducedLabelIndex.py
# sample_data				   token.txt
# tfm_BERTTokensBuilder.py		   urls_revisar.txt
# tfm_BERTUtils.py

# %%
df = pd.read_csv('reduced-model-1-training-losses-graph.csv')

# %%
plot1 = df.plot.line(x = 'Epoch', y = ['Training Loss', 'Validation Loss'] , color = ['blue', 'red'])

# %%
fig1 = plot1.get_figure()
fig1.savefig('reduced-model-1-training-losses.png')

# %%
plot2 = df.plot.line(x = 'Epoch', y = ['F1','Roc Auc','Accuracy'] , color = ['blue', 'red', 'green'])

# %%
fig2 = plot2.get_figure()
fig2.savefig('reduced-model-1-training-metrics.png')

# %%
df2 = pd.read_csv('reduced-model-1-test-set-metrics.csv')

# %%
df2.columns
# Out:
# Index(['epoch', 'f1', 'roc_auc', 'accuracy'], dtype='object')

# %%
plot3 = df2.plot.line(x = 'epoch', y = ['f1', 'roc_auc', 'accuracy'] , color = ['blue', 'red', 'green'])

# %%
fig3 = plot3.get_figure()
fig3.savefig('reduced-model-1-test-set-metrics.png')
